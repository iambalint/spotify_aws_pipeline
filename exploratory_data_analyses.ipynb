# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.0-py3-none-any.whl (30 kB)
# Collecting redis>=3.5.3
#   Downloading redis-5.2.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 kB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /root/venv/lib/python3.9/site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /root/venv/lib/python3.9/site-packages (from spotipy) (1.26.20)
# Collecting async-timeout>=4.0.3
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2024.12.14)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-5.0.1 redis-5.2.1 spotipy-2.25.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(
    client_id="19c5f6a0908748059f770f2b575d3378",
    client_secret="73e7b1086db44bca8cf4427a99222847",
)

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/5dnSFdz51E2Qouk7iFnwbl?si=9V-BrF-vQdSO8oFzTT3IjA"

# %%
playlist_URI = playlist_link.split("/")[-1].split("?")[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']['id']
data['items'][0]['track']['album']['name']
data['items'][0]['track']['album']['release_date']
data['items'][0]['track']['album']['total_tracks']
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'type': 'album',
#  'album_type': 'single',
#  'href': 'https://api.spotify.com/v1/albums/0TxewlKVKdpP18dGg279ep',
#  'id': '0TxewlKVKdpP18dGg279ep',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2734b86223903ecefaa8df576a4',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e024b86223903ecefaa8df576a4',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048514b86223903ecefaa8df576a4',
#    'width': 64}],
#  'name': 'Love Somebody',
#  'release_date': '2024-10-18',
#  'release_date_precision': 'day',
#  'uri': 'spotify:album:0TxewlKVKdpP18dGg279ep',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#    'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#    'id': '4oUHIQIBe0LHzYfvXNW4QM',
#    'name': 'Morgan Wallen',
#    'type': 'artist',
#    'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/0TxewlKVKdpP18dGg279ep'},
#  'total_tracks': 1}

# %%
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {
        'album_id': album_id,
        'album_name': album_name,
        'album_release_date': album_release_date,
        'album_total_tracks': album_total_tracks,
        'album_url': album_url
    }

    album_list.append(album_element)
# Out:
# [{'album_id': '0TxewlKVKdpP18dGg279ep',
#   'album_name': 'Love Somebody',
#   'album_release_date': '2024-10-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0TxewlKVKdpP18dGg279ep'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'album_name': 'Die With A Smile',
#   'album_release_date': '2024-08-16',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'album_name': 'Espresso',
#   'album_release_date': '2024-04-12',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '4dUAojdnh5Bcho1n8bPSO0',
#   'album_name': 'GLORIOUS',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/4dUAojdnh5Bcho1n8bPSO0'},
#  {'album_id': '2IRxVVqbSbqHJo8Zx50LYn',
#   'album_name': 'Timeless',
#   'album_release_date': '2024-09-27',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2IRxVVqbSbqHJo8Zx50LYn'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '4f2G7uAWqzpOPwEfCDV87A',
#   'album_name': 'F-1 Trillion: Long Bed',
#   'album_release_date': '2024-08-16',
#   'album_total_tracks': 27,
#   'album_url': 'https://open.spotify.com/album/4f2G7uAWqzpOPwEfCDV87A'},
#  {'album_id': '6egBeCLeGITzGSo5VyRjwZ',
#   'album_name': 'A Bar Song (Tipsy)',
#   'album_release_date': '2024-04-12',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/6egBeCLeGITzGSo5VyRjwZ'},
#  {'album_id': '2IYQwwgxgOIn7t3iF6ufFD',
#   'album_name': 'APT.',
#   'album_release_date': '2024-10-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '60cQzWfmdg4hyDXrpW6kOA',
#   'album_name': 'Tu Boda',
#   'album_release_date': '2024-09-26',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/60cQzWfmdg4hyDXrpW6kOA'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'album_name': 'Not Like Us',
#   'album_release_date': '2024-05-04',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'album_name': 'Beautiful Things',
#   'album_release_date': '2024-01-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'},
#  {'album_id': '3e5tDT1kfaAGx10yOjIDgW',
#   'album_name': 'Mantra',
#   'album_release_date': '2024-10-10',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3e5tDT1kfaAGx10yOjIDgW'},
#  {'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'album_name': 'Good Luck, Babe!',
#   'album_release_date': '2024-04-05',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#  {'album_id': '7p1fX8aUySrBdx4WSYspOu',
#   'album_name': 'Midnight Memories (Deluxe)',
#   'album_release_date': '2013-11-25',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/7p1fX8aUySrBdx4WSYspOu'},
#  {'album_id': '3VY29d0cCe38jPSYvAiI0D',
#   'album_name': 'TGIF',
#   'album_release_date': '2024-06-21',
#   'album_total_tracks': 4,
#   'album_url': 'https://open.spotify.com/album/3VY29d0cCe38jPSYvAiI0D'},
#  {'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'album_name': "I've Tried Everything But Therapy (Part 1)",
#   'album_release_date': '2023-09-15',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'},
#  {'album_id': '4dUAojdnh5Bcho1n8bPSO0',
#   'album_name': 'GLORIOUS',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/4dUAojdnh5Bcho1n8bPSO0'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '4gCNyS7pidfK3rKWhB3JOY',
#   'album_name': 'FOUR (Deluxe)',
#   'album_release_date': '2014-11-17',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/4gCNyS7pidfK3rKWhB3JOY'},
#  {'album_id': '4dUAojdnh5Bcho1n8bPSO0',
#   'album_name': 'GLORIOUS',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/4dUAojdnh5Bcho1n8bPSO0'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '62ldGEkFUkQa34B8qsAFyc',
#   'album_name': 'Lies Lies Lies',
#   'album_release_date': '2024-07-05',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/62ldGEkFUkQa34B8qsAFyc'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '27GWSFRITD8JJcSGMgEfTN',
#   'album_name': 'INCÓMODO',
#   'album_release_date': '2024-08-22',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/27GWSFRITD8JJcSGMgEfTN'},
#  {'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'album_name': 'UTOPIA',
#   'album_release_date': '2023-07-28',
#   'album_total_tracks': 19,
#   'album_url': 'https://open.spotify.com/album/18NOKLkZETa4sWwLMIm0UZ'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '27GWSFRITD8JJcSGMgEfTN',
#   'album_name': 'INCÓMODO',
#   'album_release_date': '2024-08-22',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/27GWSFRITD8JJcSGMgEfTN'},
#  {'album_id': '07w0rG5TETcyihsEIZR3qG',
#   'album_name': 'SOS',
#   'album_release_date': '2022-12-09',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/07w0rG5TETcyihsEIZR3qG'},
#  {'album_id': '3P4SQqMMgjqfqVxgLwtYRk',
#   'album_name': 'Unreal Unearth: Unheard',
#   'album_release_date': '2024-03-22',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/3P4SQqMMgjqfqVxgLwtYRk'},
#  {'album_id': '56bdWeO40o3WfAD2Lja4dl',
#   'album_name': 'The Secret of Us',
#   'album_release_date': '2024-06-21',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/56bdWeO40o3WfAD2Lja4dl'},
#  {'album_id': '6cunQQ7YZisYOoiFu2ywIq',
#   'album_name': 'Up All Night',
#   'album_release_date': '2012-05-25',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/6cunQQ7YZisYOoiFu2ywIq'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'album_name': 'Lover',
#   'album_release_date': '2019-08-23',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '0PYRiyb3VW777eQdYoI3zu',
#   'album_name': 'HIM ALL ALONG',
#   'album_release_date': '2024-10-17',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0PYRiyb3VW777eQdYoI3zu'},
#  {'album_id': '4dUAojdnh5Bcho1n8bPSO0',
#   'album_name': 'GLORIOUS',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/4dUAojdnh5Bcho1n8bPSO0'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '7aj4cB74oT3vTHDHAMaiHw',
#   'album_name': 'One Thing At A Time',
#   'album_release_date': '2023-03-03',
#   'album_total_tracks': 36,
#   'album_url': 'https://open.spotify.com/album/7aj4cB74oT3vTHDHAMaiHw'},
#  {'album_id': '40CHqDtwO8xlI3Ns7sZZel',
#   'album_name': 'ライラック',
#   'album_release_date': '2024-04-11',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/40CHqDtwO8xlI3Ns7sZZel'},
#  {'album_id': '6d5NfL24MEmiUORhMwTO0w',
#   'album_name': 'TAKE CARE',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/6d5NfL24MEmiUORhMwTO0w'},
#  {'album_id': '750APP0eKVlcgOxaZnBnVt',
#   'album_name': 'Too Hard',
#   'album_release_date': '2017-12-01',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/750APP0eKVlcgOxaZnBnVt'},
#  {'album_id': '4iqbFIdGOTzXeDtt9owjQn',
#   'album_name': "WE DON'T TRUST YOU",
#   'album_release_date': '2024-03-22',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/4iqbFIdGOTzXeDtt9owjQn'},
#  {'album_id': '4Zoxsc06EUHRf5GrJPJZ54',
#   'album_name': 'MIXTAPE PLUTO',
#   'album_release_date': '2024-09-20',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/4Zoxsc06EUHRf5GrJPJZ54'},
#  {'album_id': '6i7mF7whyRJuLJ4ogbH2wh',
#   'album_name': 'One Thing At A Time',
#   'album_release_date': '2023-03-03',
#   'album_total_tracks': 36,
#   'album_url': 'https://open.spotify.com/album/6i7mF7whyRJuLJ4ogbH2wh'},
#  {'album_id': '4dUAojdnh5Bcho1n8bPSO0',
#   'album_name': 'GLORIOUS',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/4dUAojdnh5Bcho1n8bPSO0'},
#  {'album_id': '6LU7SYL9BWAt3TgEK4DdAc',
#   'album_name': 'TAKE CARE',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/6LU7SYL9BWAt3TgEK4DdAc'},
#  {'album_id': '1U0Z7QjSzlg3gMeUOuUldz',
#   'album_name': 'The Great American Bar Scene',
#   'album_release_date': '2024-07-04',
#   'album_total_tracks': 19,
#   'album_url': 'https://open.spotify.com/album/1U0Z7QjSzlg3gMeUOuUldz'},
#  {'album_id': '5XsZ5ZTcIHnZxjynaGxA0g',
#   'album_name': 'Dancing In The Flames',
#   'album_release_date': '2024-09-13',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5XsZ5ZTcIHnZxjynaGxA0g'},
#  {'album_id': '7LRZfujsTLyy814AnMSdtT',
#   'album_name': 'Pink Skies',
#   'album_release_date': '2024-05-24',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7LRZfujsTLyy814AnMSdtT'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '5kvw1bAOvzJdNi4hdgfaNf',
#   'album_name': 'ÉXODO',
#   'album_release_date': '2024-06-20',
#   'album_total_tracks': 24,
#   'album_url': 'https://open.spotify.com/album/5kvw1bAOvzJdNi4hdgfaNf'},
#  {'album_id': '7cJpvSog0CL1J7hWZ2JtHo',
#   'album_name': 'Fall Fast in Love',
#   'album_release_date': '2024-09-27',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7cJpvSog0CL1J7hWZ2JtHo'},
#  {'album_id': '4iqbFIdGOTzXeDtt9owjQn',
#   'album_name': "WE DON'T TRUST YOU",
#   'album_release_date': '2024-03-22',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/4iqbFIdGOTzXeDtt9owjQn'},
#  {'album_id': '6tE9Dnp2zInFij4jKssysL',
#   'album_name': 'I NEVER LIKED YOU',
#   'album_release_date': '2022-04-29',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/6tE9Dnp2zInFij4jKssysL'},
#  {'album_id': '42WVQWuf1teDysXiOupIZt',
#   'album_name': 'Birds In The Trap Sing McKnight',
#   'album_release_date': '2016-09-16',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/42WVQWuf1teDysXiOupIZt'},
#  {'album_id': '7zI1wDJmkfHMBwZpbwJn8H',
#   'album_name': 'オトノケ - Otonoke',
#   'album_release_date': '2024-10-04',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/7zI1wDJmkfHMBwZpbwJn8H'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '4vLGHlTnlIIxMSfefCY0cU',
#   'album_name': 'SYNK : PARALLEL LINE - Special Digital Single',
#   'album_release_date': '2024-10-09',
#   'album_total_tracks': 4,
#   'album_url': 'https://open.spotify.com/album/4vLGHlTnlIIxMSfefCY0cU'},
#  {'album_id': '0EiI8ylL0FmWWpgHVTsZjZ',
#   'album_name': 'The Rise and Fall of a Midwest Princess',
#   'album_release_date': '2023-09-22',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/0EiI8ylL0FmWWpgHVTsZjZ'},
#  {'album_id': '4Zoxsc06EUHRf5GrJPJZ54',
#   'album_name': 'MIXTAPE PLUTO',
#   'album_release_date': '2024-09-20',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/4Zoxsc06EUHRf5GrJPJZ54'},
#  {'album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'album_name': 'Si Antes Te Hubiera Conocido',
#   'album_release_date': '2024-06-21',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5ylbxH7EqpsmHZCRuiYewS'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '3SpBlxme9WbeQdI9kx7KAV',
#   'album_name': 'Certified Lover Boy',
#   'album_release_date': '2021-09-03',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#  {'album_id': '6LU7SYL9BWAt3TgEK4DdAc',
#   'album_name': 'TAKE CARE',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/6LU7SYL9BWAt3TgEK4DdAc'},
#  {'album_id': '2Z3lIfc06B7YV1ZN9oZCdS',
#   'album_name': 'Twisters: The Album',
#   'album_release_date': '2024-07-19',
#   'album_total_tracks': 29,
#   'album_url': 'https://open.spotify.com/album/2Z3lIfc06B7YV1ZN9oZCdS'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '1fmBMCSSkSlvxyoy1vut2k',
#   'album_name': 'Saturn',
#   'album_release_date': '2024-02-22',
#   'album_total_tracks': 5,
#   'album_url': 'https://open.spotify.com/album/1fmBMCSSkSlvxyoy1vut2k'},
#  {'album_id': '1ynyQdPQiXdYJNQEDL1S3d',
#   'album_name': 'My Turn',
#   'album_release_date': '2020-02-28',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/1ynyQdPQiXdYJNQEDL1S3d'},
#  {'album_id': '6LU7SYL9BWAt3TgEK4DdAc',
#   'album_name': 'TAKE CARE',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/6LU7SYL9BWAt3TgEK4DdAc'},
#  {'album_id': '01JuX8fEX5ACudymzCB3O3',
#   'album_name': 'Help Me',
#   'album_release_date': '2024-05-31',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/01JuX8fEX5ACudymzCB3O3'},
#  {'album_id': '7p5A0E4ivsJ6Gv4iKriANy',
#   'album_name': 'Pink Pony Club',
#   'album_release_date': '2022-04-23',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7p5A0E4ivsJ6Gv4iKriANy'},
#  {'album_id': '5tSQtQGkrCJx3hoQxmLgfM',
#   'album_name': 'Gata Only',
#   'album_release_date': '2024-02-02',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5tSQtQGkrCJx3hoQxmLgfM'},
#  {'album_id': '6WKNoni6aDzCTUN1CtJJ5R',
#   'album_name': 'If I Know Me',
#   'album_release_date': '2018-04-27',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/6WKNoni6aDzCTUN1CtJJ5R'},
#  {'album_id': '1D3Uf2OkWYQytEbK3NpdMn',
#   'album_name': 'Mmhmm',
#   'album_release_date': '2023-10-06',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1D3Uf2OkWYQytEbK3NpdMn'},
#  {'album_id': '68CN2LzY8MoxO2udy2C22e',
#   'album_name': 'Sailor Song',
#   'album_release_date': '2024-07-26',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/68CN2LzY8MoxO2udy2C22e'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '6ViO9Wx6dWzeUq6DmGTaHl',
#   'album_name': 'I NEVER LIKED YOU',
#   'album_release_date': '2022-05-02',
#   'album_total_tracks': 22,
#   'album_url': 'https://open.spotify.com/album/6ViO9Wx6dWzeUq6DmGTaHl'},
#  {'album_id': '5LuoozUhs2pl3glZeAJl89',
#   'album_name': 'Scary Hours 2',
#   'album_release_date': '2021-03-05',
#   'album_total_tracks': 3,
#   'album_url': 'https://open.spotify.com/album/5LuoozUhs2pl3glZeAJl89'},
#  {'album_id': '2Z1gnUf3nbn6DtwZSUIH54',
#   'album_name': 'MILLION DOLLAR BABY',
#   'album_release_date': '2024-04-26',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/2Z1gnUf3nbn6DtwZSUIH54'},
#  {'album_id': '3VNxRarx9HUI5w7DHv0TBj',
#   'album_name': 'Stargazing',
#   'album_release_date': '2024-05-10',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3VNxRarx9HUI5w7DHv0TBj'},
#  {'album_id': '4dUAojdnh5Bcho1n8bPSO0',
#   'album_name': 'GLORIOUS',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/4dUAojdnh5Bcho1n8bPSO0'},
#  {'album_id': '2uDTi1PlpSpvAv7IRAoAEU',
#   'album_name': 'HIGHEST IN THE ROOM',
#   'album_release_date': '2019-10-04',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2uDTi1PlpSpvAv7IRAoAEU'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '6PbnGueEO6LGodPfvNldYf',
#   'album_name': 'Zach Bryan',
#   'album_release_date': '2023-08-25',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/6PbnGueEO6LGodPfvNldYf'},
#  {'album_id': '3iRQdNKyI5Pf78jWYI1tFv',
#   'album_name': 'PERO NO TE ENAMORES',
#   'album_release_date': '2024-07-25',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/3iRQdNKyI5Pf78jWYI1tFv'},
#  {'album_id': '2aM3higgzzkjpJf4EDJ8Gq',
#   'album_name': 'Piece of My Heart (feat. Brent Faiyaz)',
#   'album_release_date': '2024-10-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2aM3higgzzkjpJf4EDJ8Gq'},
#  {'album_id': '0O5WgUe2bObIlk6R0nwOs2',
#   'album_name': 'Or What',
#   'album_release_date': '2024-09-06',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/0O5WgUe2bObIlk6R0nwOs2'},
#  {'album_id': '1ATL5GLyefJaxhQzSPVrLX',
#   'album_name': 'Scorpion',
#   'album_release_date': '2018-06-29',
#   'album_total_tracks': 25,
#   'album_url': 'https://open.spotify.com/album/1ATL5GLyefJaxhQzSPVrLX'},
#  {'album_id': '4dUAojdnh5Bcho1n8bPSO0',
#   'album_name': 'GLORIOUS',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/4dUAojdnh5Bcho1n8bPSO0'},
#  {'album_id': '50ZenUP4O2Q5eCy2NRNvuz',
#   'album_name': 'Stick Season',
#   'album_release_date': '2022-10-14',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/50ZenUP4O2Q5eCy2NRNvuz'},
#  {'album_id': '4ffJTc6OVVJ7rr65r5CGbq',
#   'album_name': 'Last Lap',
#   'album_release_date': '2024-10-11',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/4ffJTc6OVVJ7rr65r5CGbq'},
#  {'album_id': '0nIHweIUCe2nVy5stte3GY',
#   'album_name': 'NEW LOOK',
#   'album_release_date': '2024-10-09',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0nIHweIUCe2nVy5stte3GY'},
#  {'album_id': '0hHXTxICTlnURMkIEfz3It',
#   'album_name': 'Spin You Around (1/24)',
#   'album_release_date': '2024-01-26',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0hHXTxICTlnURMkIEfz3It'}]

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_name': artist['name'], 'external_url': artist['external_urls']['spotify']}
                artist_list.append(artist_dict)
artist_list
# Out:
# [{'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://open.spotify.com/artist/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '3DbwFQlvLxRSi2uX8mf81A',
#   'artist_name': 'Sexyy Red',
#   'external_url': 'https://open.spotify.com/artist/3DbwFQlvLxRSi2uX8mf81A'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://open.spotify.com/artist/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '3y2cIKLjiOlp1Np37WiUdH',
#   'artist_name': 'Shaboozey',
#   'external_url': 'https://open.spotify.com/artist/3y2cIKLjiOlp1Np37WiUdH'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '3l9G1G9MxH6DaRhwLklaf5',
#   'artist_name': 'Oscar Maydon',
#   'external_url': 'https://open.spotify.com/artist/3l9G1G9MxH6DaRhwLklaf5'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'external_url': 'https://open.spotify.com/artist/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_url': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '250b0Wlc5Vk0CoUsaCY84M',
#   'artist_name': 'JENNIE',
#   'external_url': 'https://open.spotify.com/artist/250b0Wlc5Vk0CoUsaCY84M'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '4AK6F7OLvEQ5QYCBNiQWHq',
#   'artist_name': 'One Direction',
#   'external_url': 'https://open.spotify.com/artist/4AK6F7OLvEQ5QYCBNiQWHq'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://open.spotify.com/artist/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'external_url': 'https://open.spotify.com/artist/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://open.spotify.com/artist/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '4AK6F7OLvEQ5QYCBNiQWHq',
#   'artist_name': 'One Direction',
#   'external_url': 'https://open.spotify.com/artist/4AK6F7OLvEQ5QYCBNiQWHq'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://open.spotify.com/artist/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '3aQeKQSyrW4qWr35idm0cy',
#   'artist_name': 'T-Pain',
#   'external_url': 'https://open.spotify.com/artist/3aQeKQSyrW4qWr35idm0cy'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'external_url': 'https://open.spotify.com/artist/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://open.spotify.com/artist/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'external_url': 'https://open.spotify.com/artist/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '2FXC3k01G6Gw61bmprjgqS',
#   'artist_name': 'Hozier',
#   'external_url': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'external_url': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '4AK6F7OLvEQ5QYCBNiQWHq',
#   'artist_name': 'One Direction',
#   'external_url': 'https://open.spotify.com/artist/4AK6F7OLvEQ5QYCBNiQWHq'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '6icQOAFXDZKsumw3YXyusw',
#   'artist_name': 'Lil Yachty',
#   'external_url': 'https://open.spotify.com/artist/6icQOAFXDZKsumw3YXyusw'},
#  {'artist_id': '5f7VJjfbwm532GiveGC0ZK',
#   'artist_name': 'Lil Baby',
#   'external_url': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '2hlmm7s2ICUX0LVIhVFlZQ',
#   'artist_name': 'Gunna',
#   'external_url': 'https://open.spotify.com/artist/2hlmm7s2ICUX0LVIhVFlZQ'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://open.spotify.com/artist/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'artist_name': 'Latto',
#   'external_url': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '4GGfAshSkqoxpZdoaHm7ky',
#   'artist_name': 'ERNEST',
#   'external_url': 'https://open.spotify.com/artist/4GGfAshSkqoxpZdoaHm7ky'},
#  {'artist_id': '4QvgGvpgzgyUOo8Yp8LDm9',
#   'artist_name': 'Mrs. GREEN APPLE',
#   'external_url': 'https://open.spotify.com/artist/4QvgGvpgzgyUOo8Yp8LDm9'},
#  {'artist_id': '6qxpnaukVayrQn6ViNvu9I',
#   'artist_name': 'BigXthaPlug',
#   'external_url': 'https://open.spotify.com/artist/6qxpnaukVayrQn6ViNvu9I'},
#  {'artist_id': '5f7VJjfbwm532GiveGC0ZK',
#   'artist_name': 'Lil Baby',
#   'external_url': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp',
#   'artist_name': 'Metro Boomin',
#   'external_url': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://open.spotify.com/artist/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '181bsRPaVXVlUKXrxwZfHK',
#   'artist_name': 'Megan Thee Stallion',
#   'external_url': 'https://open.spotify.com/artist/181bsRPaVXVlUKXrxwZfHK'},
#  {'artist_id': '6qxpnaukVayrQn6ViNvu9I',
#   'artist_name': 'BigXthaPlug',
#   'external_url': 'https://open.spotify.com/artist/6qxpnaukVayrQn6ViNvu9I'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://open.spotify.com/artist/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://open.spotify.com/artist/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '6pV5zH2LzjOUHaAvENdMMa',
#   'artist_name': 'Neton Vega',
#   'external_url': 'https://open.spotify.com/artist/6pV5zH2LzjOUHaAvENdMMa'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp',
#   'artist_name': 'Metro Boomin',
#   'external_url': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://open.spotify.com/artist/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '687cZJR45JO7jhk1LHIbgq',
#   'artist_name': 'Tems',
#   'external_url': 'https://open.spotify.com/artist/687cZJR45JO7jhk1LHIbgq'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '0pWR7TsFhvSCnbmHDjWgrE',
#   'artist_name': 'Creepy Nuts',
#   'external_url': 'https://open.spotify.com/artist/0pWR7TsFhvSCnbmHDjWgrE'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '6YVMFz59CuY7ngCxTxjpxE',
#   'artist_name': 'aespa',
#   'external_url': 'https://open.spotify.com/artist/6YVMFz59CuY7ngCxTxjpxE'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '1URnnhqYAYcrqrcwql10ft',
#   'artist_name': '21 Savage',
#   'external_url': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#  {'artist_id': '08Ld63UgKrJ0nZnCkzHtzc',
#   'artist_name': 'Project Pat',
#   'external_url': 'https://open.spotify.com/artist/08Ld63UgKrJ0nZnCkzHtzc'},
#  {'artist_id': '6qxpnaukVayrQn6ViNvu9I',
#   'artist_name': 'BigXthaPlug',
#   'external_url': 'https://open.spotify.com/artist/6qxpnaukVayrQn6ViNvu9I'},
#  {'artist_id': '718COspgdWOnwOFpJHRZHS',
#   'artist_name': 'Luke Combs',
#   'external_url': 'https://open.spotify.com/artist/718COspgdWOnwOFpJHRZHS'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '2rTZSJ6JzWaKJaHGbEkRjl',
#   'artist_name': 'Be Charlotte',
#   'external_url': 'https://open.spotify.com/artist/2rTZSJ6JzWaKJaHGbEkRjl'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '5f7VJjfbwm532GiveGC0ZK',
#   'artist_name': 'Lil Baby',
#   'external_url': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#  {'artist_id': '6qxpnaukVayrQn6ViNvu9I',
#   'artist_name': 'BigXthaPlug',
#   'external_url': 'https://open.spotify.com/artist/6qxpnaukVayrQn6ViNvu9I'},
#  {'artist_id': '1iwUuIOKYjV7SKIg27v4zi',
#   'artist_name': 'Real Boston Richey',
#   'external_url': 'https://open.spotify.com/artist/1iwUuIOKYjV7SKIg27v4zi'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'external_url': 'https://open.spotify.com/artist/7CvTknweLr9feJtRGrpDBy'},
#  {'artist_id': '1Yj5Xey7kTwvZla8sqdsdE',
#   'artist_name': 'Cris Mj',
#   'external_url': 'https://open.spotify.com/artist/1Yj5Xey7kTwvZla8sqdsdE'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '6qxpnaukVayrQn6ViNvu9I',
#   'artist_name': 'BigXthaPlug',
#   'external_url': 'https://open.spotify.com/artist/6qxpnaukVayrQn6ViNvu9I'},
#  {'artist_id': '1iCnM8foFssWlPRLfAbIwo',
#   'artist_name': 'Gigi Perez',
#   'external_url': 'https://open.spotify.com/artist/1iCnM8foFssWlPRLfAbIwo'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '45gHcnDnMC15sgx3VL7ROG',
#   'artist_name': '42 Dugg',
#   'external_url': 'https://open.spotify.com/artist/45gHcnDnMC15sgx3VL7ROG'},
#  {'artist_id': '5f7VJjfbwm532GiveGC0ZK',
#   'artist_name': 'Lil Baby',
#   'external_url': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '5f7VJjfbwm532GiveGC0ZK',
#   'artist_name': 'Lil Baby',
#   'external_url': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#  {'artist_id': '1WaFQSHVGZQJTbf0BdxdNo',
#   'artist_name': 'Tommy Richman',
#   'external_url': 'https://open.spotify.com/artist/1WaFQSHVGZQJTbf0BdxdNo'},
#  {'artist_id': '3bO19AOone0ubCsfDXDtYt',
#   'artist_name': 'Myles Smith',
#   'external_url': 'https://open.spotify.com/artist/3bO19AOone0ubCsfDXDtYt'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://open.spotify.com/artist/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://open.spotify.com/artist/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '70kkdajctXSbqSMJbQO424',
#   'artist_name': 'Kacey Musgraves',
#   'external_url': 'https://open.spotify.com/artist/70kkdajctXSbqSMJbQO424'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'external_url': 'https://open.spotify.com/artist/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '3tVQdUvClmAT7URs9V3rsp',
#   'artist_name': 'Wizkid',
#   'external_url': 'https://open.spotify.com/artist/3tVQdUvClmAT7URs9V3rsp'},
#  {'artist_id': '3tlXnStJ1fFhdScmQeLpuG',
#   'artist_name': 'Brent Faiyaz',
#   'external_url': 'https://open.spotify.com/artist/3tlXnStJ1fFhdScmQeLpuG'},
#  {'artist_id': '0ErzCpIMyLcjPiwT4elrtZ',
#   'artist_name': 'NLE Choppa',
#   'external_url': 'https://open.spotify.com/artist/0ErzCpIMyLcjPiwT4elrtZ'},
#  {'artist_id': '0yknvLWQZxwsMjhUhwWZQ8',
#   'artist_name': '41',
#   'external_url': 'https://open.spotify.com/artist/0yknvLWQZxwsMjhUhwWZQ8'},
#  {'artist_id': '0hF6lbAjRsq4svrQUr5sgU',
#   'artist_name': 'Kyle Richh',
#   'external_url': 'https://open.spotify.com/artist/0hF6lbAjRsq4svrQUr5sgU'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://open.spotify.com/artist/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '23xFbA9rYgRX8mreqysWPc',
#   'artist_name': 'BossMan Dlow',
#   'external_url': 'https://open.spotify.com/artist/23xFbA9rYgRX8mreqysWPc'},
#  {'artist_id': '2RQXRUsr4IW1f3mKyKsy4B',
#   'artist_name': 'Noah Kahan',
#   'external_url': 'https://open.spotify.com/artist/2RQXRUsr4IW1f3mKyKsy4B'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '0IwZVmMMGE7nNXS7vN9SIo',
#   'artist_name': 'MISAMO',
#   'external_url': 'https://open.spotify.com/artist/0IwZVmMMGE7nNXS7vN9SIo'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration_ms = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added_at = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['artists'][0]['id']
    song_element = {
        'song_id': song_id,
        'song_name': song_name,
        'song_duration_ms': song_duration_ms,
        'song_url': song_url,
        'song_popularity': song_popularity,
        'song_added_at': song_added_at,
        'album_id': album_id,
        'artist_id': artist_id
    }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)
artist_df = pd.DataFrame.from_dict(artist_list)
song_df = pd.DataFrame.from_dict(song_list)

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
album_df['release_date'] = pd.to_datetime(album_df['album_release_date'])
song_df['song_added_at'] = pd.to_datetime(song_df['song_added_at'])

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1160f8c3-e6bd-4271-83c7-8fd40d4fbd57' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
